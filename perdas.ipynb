# %% [markdown]
# <a href="https://colab.research.google.com/github/allanzim/Trabalho/blob/master/perdas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  # %pip install sidetable

  import numpy as np
  import pandas as pd

  import sidetable
  from scipy import stats

  import seaborn as sns
  import matplotlib.pyplot as plt

  import plotly.express as px
  import plotly.graph_objects as go
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df = pd.read_excel('/content/Relatorio__Unidades_por_Consumo-20221118-110721-433421204.xlsx')
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df
# Out:
#        Relatório: Unidades por Consumo Unnamed: 1                  Unnamed: 2  \
# 0      Relatório: Unidades por Consumo        NaN                         NaN
# 1                                             NaN                         NaN
# 2                            MATRICULA      GRUPO           NOME_PROPRIETARIO
# 3                             186116-6        111     KLEITON FERREIRA RIGONE
# 4                             186117-4        111      MALLANY NEVES DE SOUZA
# ...                                ...        ...                         ...
# 16655                         450664-2        116  ANTONIO RODRIGUES DA SILVA
# 16656                         450665-0        116  ANTONIO RODRIGUES DA SILVA
# 16657                         450666-9        116  ANTONIO RODRIGUES DA SILVA
# 16658                         450672-3        117     WILTO FERREIRA BARCELOS
# 16659                         450675-8        117     GILDO XAVIER NEPOMUCENO
#
# ...

# %%
df = pd.read_excel('/content/data_frame.xlsx')
# Out:
#       MATRICULA  GRUPO                    NOME_PROPRIETARIO  \
# 0      186116-6    111              KLEITON FERREIRA RIGONE
# 1      186117-4    111               MALLANY NEVES DE SOUZA
# 2      186119-0    111  LOJA MACONICA OBREIROS DA LIBERDADE
# 3      186120-4    111          JUNICLER CRISTIANE DA SILVA
# 4      186121-2    111            ANTONIO BERNARDO DA COSTA
# ...         ...    ...                                  ...
# 16652  450664-2    116           ANTONIO RODRIGUES DA SILVA
# 16653  450665-0    116           ANTONIO RODRIGUES DA SILVA
# 16654  450666-9    116           ANTONIO RODRIGUES DA SILVA
# 16655  450672-3    117              WILTO FERREIRA BARCELOS
# 16656  450675-8    117              GILDO XAVIER NEPOMUCENO
#
#                               NOME_MORADOR  \
# 0                  KLEITON FERREIRA RIGONE
# 1                   MALLANY NEVES DE SOUZA
# 2      LOJA MACONICA OBREIROS DA LIBERDADE
# 3              JUNICLER CRISTIANE DA SILVA
# ...

# %%
df
# Out:
#       MATRICULA  GRUPO                    NOME_PROPRIETARIO  \
# 0      186116-6    111              KLEITON FERREIRA RIGONE
# 1      186117-4    111               MALLANY NEVES DE SOUZA
# 2      186119-0    111  LOJA MACONICA OBREIROS DA LIBERDADE
# 3      186120-4    111          JUNICLER CRISTIANE DA SILVA
# 4      186121-2    111            ANTONIO BERNARDO DA COSTA
# ...         ...    ...                                  ...
# 16652  450664-2    116           ANTONIO RODRIGUES DA SILVA
# 16653  450665-0    116           ANTONIO RODRIGUES DA SILVA
# 16654  450666-9    116           ANTONIO RODRIGUES DA SILVA
# 16655  450672-3    117              WILTO FERREIRA BARCELOS
# 16656  450675-8    117              GILDO XAVIER NEPOMUCENO
#
#                               NOME_MORADOR  \
# 0                  KLEITON FERREIRA RIGONE
# 1                   MALLANY NEVES DE SOUZA
# 2      LOJA MACONICA OBREIROS DA LIBERDADE
# 3              JUNICLER CRISTIANE DA SILVA
# ...

# %%
df['VOLUME_LIDO'].sum()
# Out:
# 212378.0

# %%
df[(df['TIPO_CONSUMO_FATURADO']=='Lido')]
# Out:
#       MATRICULA  GRUPO           NOME_PROPRIETARIO  \
# 0      186116-6    111     KLEITON FERREIRA RIGONE
# 1      186117-4    111      MALLANY NEVES DE SOUZA
# 4      186121-2    111   ANTONIO BERNARDO DA COSTA
# 5      186122-0    111     DINAH GARCIA DE FREITAS
# 6      186123-9    111             MAURICIO VIEIRA
# ...         ...    ...                         ...
# 16652  450664-2    116  ANTONIO RODRIGUES DA SILVA
# 16653  450665-0    116  ANTONIO RODRIGUES DA SILVA
# 16654  450666-9    116  ANTONIO RODRIGUES DA SILVA
# 16655  450672-3    117     WILTO FERREIRA BARCELOS
# 16656  450675-8    117     GILDO XAVIER NEPOMUCENO
#
#                      NOME_MORADOR                                    ENDERECO  \
# 0         KLEITON FERREIRA RIGONE   Avenida  VEREADOR VALTER DE OLIVEIRA, 838
# 1          MALLANY NEVES DE SOUZA   Avenida  VEREADOR VALTER DE OLIVEIRA, 874
# 4       ANTONIO BERNARDO DA COSTA   Avenida  VEREADOR VALTER DE OLIVEIRA, 970
# ...

# %%
df_filled = df.fillna(0)

df_filled[(df_filled['CONSUMO_FATURADO']==0) & (df_filled['TIPO_CONSUMO_FATURADO']=='Lido') & (df_filled['SITUACAO_LIG_AGUA']=='Ativa') & (df_filled['MEDIA_MES_ANTERIOR']!= 0)]
# Out:
#       MATRICULA  GRUPO                 NOME_PROPRIETARIO  \
# 1401   187804-2    103           LUCIANA CANDIDA DA MATA
# 6839   437727-3    105             ANA RODRIGUES DA CRUZ
# 9442   442658-4    116         RAIMUNDO VANTUIL DA SILVA
# 10302  443610-5    117             ADAO MARTINS DA SILVA
# 11099  444498-1    111  RAFAEL EDUARDO GOMES DE OLIVEIRA
# 15187  449014-2    110           LEANDRO MACIEL FLAUSINO
#
#                            NOME_MORADOR                              ENDERECO  \
# 1401            LUCIANA CANDIDA DA MATA         Rua  ANTONIO BENTO NETO, 1114
# 6839               DIOGO KELER DA SILVA             Rua  MANOEL F PEREIRA, 73
# 9442          RAIMUNDO VANTUIL DA SILVA  Avenida  JOSE MARTINS MONTEIRO, 2427
# 10302             ADAO MARTINS DA SILVA            Rua  JOSÉ R. MURTINHO, 268
# 11099  RAFAEL EDUARDO GOMES DE OLIVEIRA  Rua   SENADOR ULISSES GUIMARAES, 590
# 15187           LEANDRO MACIEL FLAUSINO                    Rua  DR. FILÓ, 594
#
# ...

# %%
df_filled[(df_filled['NUMERO_DE_DIAS_DE_CONSUMO']>=35) & (df_filled['TIPO_CONSUMO_FATURADO']=='Lido')]
# Out:
#       MATRICULA  GRUPO                    NOME_PROPRIETARIO  \
# 42     186165-4    111                    CESAR SUARDI NETO
# 273    186431-9    101          ELZA RODRIGUES DA SILVA LUZ
# 394    186575-7    101     MANOEL MESSIAS GOMES DE OLIVEIRA
# 1848   188339-9    101                   LAURA GOMES SOARES
# 1971   188481-6    102                 ZOLITA LIMA DA COSTA
# 2073   188591-0    102           DANIELLA FERREIRA DA SILVA
# 2300   188838-2    106              LEANDRO FERNANDES GOMES
# 2330   188868-4    106           FRANCISCO VALDENOR BARBOSA
# 2967   319596-1    109            ROSANGELA DE JESUS PAIXAO
# 3104   319750-6    110          JOAQUIM SERAFIM DE OLIVEIRA
# 3349   334889-0    109                         EMIR DE LANA
# 4021   416315-0    109                NOEMIA LUIZ DE CASTRO
# 4347   426012-0    109            LUCIANO MARTINHO DA SILVA
# 5185   433241-5    104            EVANILDE DE SOUZA MARTINS
# 5854   435043-0    113            AGUINALDO LEONEL DA SILVA
# ...

# %%
# df_filtrado = pd.isnull(df['NUMERO_DE_DIAS_DE_CONSUMO'])
df_filtrado = pd.isnull(df['NUMERO_DE_DIAS_DE_CONSUMO']).count()

df_filtrado
# Out:
# 16657

# %%
df_filtro1 = df[(df['N_HIDROMETRO'] == 'NÃO HÁ HIDROMETRO') & (df['SITUACAO_LIG_AGUA'] == 'Ativa')]

df_filtro1.count()
# Out:
# MATRICULA                    64
# GRUPO                        64
# NOME_PROPRIETARIO            64
# NOME_MORADOR                 64
# ENDERECO                     64
# COMPLEMENTO                  30
# BAIRRO                       64
# LOCALIZACAO                  64
# SITUACAO_LIG_AGUA            64
# LIGACAO_PARTICULAR           64
# N_HIDROMETRO                 64
# ORIGEM_DA_AGUA                0
# VOLUME_LIDO                   0
# OCORRENCIA                   64
# DESC_OCORRENCIA               0
# CONSUMO_FATURADO             64
# TIPO_CONSUMO_FATURADO        64
# DATA_DA_LEITURA              63
# NUMERO_DE_DIAS_DE_CONSUMO     0
# MEDIA_MES_ANTERIOR           32
# dtype: int64

# %%
df_filtro1
# Out:
#       MATRICULA  GRUPO                 NOME_PROPRIETARIO  \
# 202    186353-3    103            MARIA LEONTINA VALADÃO
# 323    186493-9    101  DIVINA FERREIRA FELICIANA MORAES
# 710    186985-0    103       GILMAR DE CARVALHO NOGUEIRA
# 792    187085-8    103       CLEMILTON MACEDO DE MIRANDA
# 1159   187504-3    101                     JOSE RAIMUNDO
# ...         ...    ...                               ...
# 16652  450664-2    116        ANTONIO RODRIGUES DA SILVA
# 16653  450665-0    116        ANTONIO RODRIGUES DA SILVA
# 16654  450666-9    116        ANTONIO RODRIGUES DA SILVA
# 16655  450672-3    117           WILTO FERREIRA BARCELOS
# 16656  450675-8    117           GILDO XAVIER NEPOMUCENO
#
#                       NOME_MORADOR                                 ENDERECO  \
# 202      GENIVAL DOS SANTOS GARCIA              Avenida   MATO GROSSO, 1383
# 323    RAFAEL FELICIANO DE ALMEIDA     Avenida  JOSE MARTINS MONTEIRO, 1498
# ...

# %%
df_filtro1.to_excel('/content/Planilha_Ligação_ATIVA_Sem_Hidrometro.xlsx')

# %%
df_setembro = pd.read_excel('/content/Relatorio__Unidades_por_Consumo-Setembro.xlsx')

# %%
df_setembro[df_setembro['SITUACAO_LIG_AGUA']== 'Suprimida']
# Out:
#       MATRICULA  GRUPO              NOME_PROPRIETARIO  \
# 3      186120-4    111    JUNICLER CRISTIANE DA SILVA
# 13     186131-0    111                   JOÃO BATISTA
# 41     186164-6    111             ELVIRA ELZA MIELKE
# 80     186205-7    112          WILIAN JAIME OLIVEIRA
# 273    186432-7    102      IRAIDES PARREIRA DA SILVA
# ...         ...    ...                            ...
# 14356  448117-8    104             GLEISE AMELIA DIAS
# 14547  448319-7    104  NEW TECH REFRIGERAÇÃO LTDA ME
# 15110  448949-7    110           LOCIBIO REZENDE LEAL
# 15957  449907-7    116           MARILCE SANTOS LEITE
# 16086  450049-0    117           WESLA KENIA ZEFERINO
#
#                         NOME_MORADOR                             ENDERECO  \
# 3        JUNICLER CRISTIANE DA SILVA  Rua   MARIANO PIRES DE CAMPOS, 1734
# 13                      JOÃO BATISTA  Rua   MARIANO PIRES DE CAMPOS, 1640
# 41                ELVIRA ELZA MIELKE           Avenida  ANTÔNIO MAGIO, SN
# ...

# %%
df_set_filtro = df_setembro[(df_setembro['SITUACAO_LIG_AGUA']== 'Ativa') & (df_setembro['N_HIDROMETRO'] == 'NÃO HÁ HIDROMETRO')]

df_set_filtro
# Out:
#       MATRICULA  GRUPO                      NOME_PROPRIETARIO  \
# 42     186165-4    111                      CESAR SUARDI NETO
# 132    186266-9    101  THAYSA BEATRIZ FERREIRA OLANDA FERRAZ
# 153    186296-0    101                       LASARO FLORENCIO
# 201    186353-3    103                 MARIA LEONTINA VALADÃO
# 272    186431-9    101            ELZA RODRIGUES DA SILVA LUZ
# ...         ...    ...                                    ...
# 16567  450618-9    118     CAMILA APARECIDA CARVALHO OLIVEIRA
# 16568  450621-9    118                     NILTON CEZAR SIMÃO
# 16569  450622-7    118               MARCOS DA COSTA DE JESUS
# 16570  450626-0    118              JADILSON ANTONIO DA SILVA
# 16571  450629-4    118             SEBASTIAO MOISEIS DA SILVA
#
#                                 NOME_MORADOR  \
# 42                    LARISSE PEREIRA AMORIM
# 132    THAYSA BEATRIZ FERREIRA OLANDA FERRAZ
# 153         CARLOS EDUARDO TONCHIS FLORENCIO
# ...

# %%
df_setembro_filled = df_setembro[(df_setembro['CONSUMO_FATURADO']==0) & (df_setembro['SITUACAO_LIG_AGUA']=='Ativa')].fillna(0)

# %%
df_setembro_filled[df_setembro_filled['MEDIA_MES_ANTERIOR']!=0].to_excel('/content/teste.xlsx')

# %%
df_set_index = df_set_filtro['MATRICULA'].reset_index()

df_set_index
# Out:
#     index MATRICULA
# 0      42  186165-4
# 1     132  186266-9
# 2     153  186296-0
# 3     201  186353-3
# 4     272  186431-9
# ..    ...       ...
# 93  16567  450618-9
# 94  16568  450621-9
# 95  16569  450622-7
# 96  16570  450626-0
# 97  16571  450629-4
#
# [98 rows x 2 columns]

# %%
df_set_index
# Out:
#     index MATRICULA
# 0      42  186165-4
# 1     132  186266-9
# 2     153  186296-0
# 3     201  186353-3
# 4     272  186431-9
# ..    ...       ...
# 93  16567  450618-9
# 94  16568  450621-9
# 95  16569  450622-7
# 96  16570  450626-0
# 97  16571  450629-4
#
# [98 rows x 2 columns]
